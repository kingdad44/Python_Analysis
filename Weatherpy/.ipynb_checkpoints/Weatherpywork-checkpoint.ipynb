# %% [markdown]
# __Resources__<br>
# I will be using numpy pandas matplotlib and citipy packages and the open weather wrapper

# %%
#import dependencies
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import requests as req
import json
import time
import os
from config import opwther_key
sample_out = "SampleCoords.csv"
import datetime


now = datetime.date.today()

data_file = "sample_data"

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
appid = opwther_key
settings = {"units": "imperial", "appid":opwther_key}
query_url = f"{url}appid={opwther_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=

# %% [markdown]
# __ Gathering Random City Samples__<br>
# I will accomplish this by retreiving a city list from citipy by iterating through latitude and longitude<br>
# values and retreiving city names where there are matches using the citipy nearest_city function.<br>
# This will create duplicates that will be removed before sampling. <br>
# The latitude and longitude values will include the entire globe.<br>
# I chose to sample the globe in quadrants seperately to ensure even distriubtion of samples<br>
# ![Lat_Long.gif](attachment:Lat_Long.gif)<br>
# Image source = http://learner.org/jnorth/tm/LongitudeIntro.html

# %%
#create empty list
north_citylist = []

count = 0
dup = 'no'
#cycle through lat long values
for x in range(0,90,1):
    for y in range(-180,180,1):
        city = citipy.nearest_city(x, y)
        citdict = {}
        citdict['city'] = city.city_name
        citdict['country'] = city.country_code
        citdict['lat'] = x
        citdict['long'] = y
         #insert first value
        if len(north_citylist) == 0:
            north_citylist.append(citdict)
            count+=1
            continue
        else:
                 #skip record if city is already in dictionary
            for city in north_citylist:
                if city['city'] == citdict['city']:
                    dup = 'yes'
        if dup == 'no':
            north_citylist.append(citdict)
            count+=1
        else:
            dup = 'no'
            
north_df = pd.DataFrame({
    'city': [x['city'] for x in north_citylist],
    'country': [x['country'] for x in north_citylist],
    'lat':[x['lat'] for x in north_citylist],
    'long':[x['long'] for x in north_citylist]})

#sample south values for 250 samples
north_sample_df= north_df.sample(250)

# %%
#create empty list
south_citylist =[]
count = 0
dup = 'no'
#cycle through lat long values
for x in range(-90,-1,1):
    for y in range(-180,180,1):
        # call nearest_city function from city py and append results to dictionary
        city = citipy.nearest_city(x, y)
        citdict = {}
        citdict['city'] = city.city_name
        citdict['country'] = city.country_code
        citdict['lat'] = x
        citdict['long'] = y
        #insert first value
        if len(south_citylist) == 0:
            south_citylist.append(citdict)
            count+=1
            continue
        #skip record if city is already in dictionary
        else:
            for city in south_citylist:
                if city['city'] == citdict['city']:
                    dup = 'yes'
        if dup == 'no':
            south_citylist.append(citdict)
            count+=1
        else:
            dup = 'no'
            
south_df = pd.DataFrame({
    'city': [x['city'] for x in south_citylist],
    'country': [x['country'] for x in south_citylist],
    'lat':[x['lat'] for x in south_citylist],
    'long':[x['long'] for x in south_citylist]})

#sample south values for 250 samples
south_sample_df= south_df.sample(250)

# %%
#append both samples to common dataframe
city_sample_df=south_sample_df
city_sample_df=city_sample_df.append(north_sample_df)


city_sample_df.head()
#check results
print(len(city_sample_df))
# Out:
# 500

# %%
city_sample_df.head()
# Out:
#             city country  lat  long
# 1282      liwale      tz  -10    37
# 184    warkworth      nz  -36   175
# 484     bengkulu      id  -26    86
# 1422  ngerengere      tz   -7    38
# 1428   kadungora      id   -7   108

# %%
#Validate Sampling moethods
print("Northern Hemisphere City Totals : " + str(len(north_df)))

print("Southern Hemisphere City Totals : " + str(len(south_df)))
# Out:
# Northern Hemisphere City Totals : 6273
# Southern Hemisphere City Totals : 1764

# %% [markdown]
# __ Key Differences In City Counts__<br>
# There are significantly more cities in the northern hemisphere<br>
# This validates my sampling method of splitting and joining the samples.<br>

# %%
count = 0
weather_json = []

for index,row in city_sample_df.iterrows():
    count+= 1
    query_url = url + "appid=" + opwther_key + "&units=" + units + "&q=" + row['city']
    try:
        weather_response = req.get(query_url)
        cityweather = weather_response.json()
        weather_json.append(cityweather)
        city1 = data.get("name")
        city.append(city1)
        country1 = data.get("sys").get("country")
        country.append(country1)
    except:
        #print(f"No data for this city: {row['city']}")
        print(f"Processing Record {count} for {row['city']} , {row['country']}")

        print(query_url)

print("                Data Retrieval Complete")
# Out:
# Processing Record 1 for liwale , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=liwale
# Processing Record 2 for warkworth , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=warkworth
# Processing Record 3 for bengkulu , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bengkulu
# Processing Record 4 for ngerengere , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ngerengere
# Processing Record 5 for kadungora , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kadungora
# Processing Record 6 for conchas , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=conchas
# Processing Record 7 for capitan bado , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=capitan bado
# Processing Record 8 for jardim , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jardim
# Processing Record 9 for breyten , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=breyten
# Processing Record 10 for tupancireta , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tupancireta
# Processing Record 11 for solwezi , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=solwezi
# Processing Record 12 for tome , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tome
# Processing Record 13 for manaus , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=manaus
# Processing Record 14 for biloela , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=biloela
# Processing Record 15 for laela , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=laela
# Processing Record 16 for ushuaia , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ushuaia
# Processing Record 17 for la plata , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=la plata
# Processing Record 18 for santo augusto , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santo augusto
# Processing Record 19 for namatanai , pg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=namatanai
# Processing Record 20 for wanganui , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=wanganui
# Processing Record 21 for chingola , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chingola
# Processing Record 22 for kokoda , pg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kokoda
# Processing Record 23 for deneysville , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=deneysville
# Processing Record 24 for kaitangata , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kaitangata
# Processing Record 25 for kruisfontein , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kruisfontein
# Processing Record 26 for porciuncula , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=porciuncula
# Processing Record 27 for lae , pg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lae
# Processing Record 28 for magomeni , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=magomeni
# Processing Record 29 for ruteng , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ruteng
# Processing Record 30 for bela vista de goias , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bela vista de goias
# Processing Record 31 for curaca , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=curaca
# Processing Record 32 for naberera , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=naberera
# Processing Record 33 for sorong , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sorong
# Processing Record 34 for uyuni , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=uyuni
# Processing Record 35 for la peca , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=la peca
# Processing Record 36 for torata , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=torata
# Processing Record 37 for benalla , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=benalla
# Processing Record 38 for grootfontein , na
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=grootfontein
# Processing Record 39 for villa carlos paz , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=villa carlos paz
# Processing Record 40 for kobojango , bw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kobojango
# Processing Record 41 for rosario , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rosario
# Processing Record 42 for quatre cocos , mu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=quatre cocos
# Processing Record 43 for caceres , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=caceres
# Processing Record 44 for gamba , ga
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gamba
# Processing Record 45 for te anau , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=te anau
# Processing Record 46 for ambilobe , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ambilobe
# Processing Record 47 for gizo , sb
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gizo
# Processing Record 48 for karibib , na
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=karibib
# Processing Record 49 for ambulu , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ambulu
# Processing Record 50 for lazaro cardenas , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lazaro cardenas
# Processing Record 51 for inongo , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=inongo
# Processing Record 52 for formosa , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=formosa
# Processing Record 53 for moindou , nc
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=moindou
# Processing Record 54 for sao joao do paraiso , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao joao do paraiso
# Processing Record 55 for namwala , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=namwala
# Processing Record 56 for abancay , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=abancay
# Processing Record 57 for nyamuswa , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nyamuswa
# Processing Record 58 for aguas formosas , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=aguas formosas
# Processing Record 59 for iquitos , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=iquitos
# Processing Record 60 for palabuhanratu , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=palabuhanratu
# Processing Record 61 for namanyere , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=namanyere
# Processing Record 62 for madimba , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=madimba
# Processing Record 63 for rurrenabaque , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rurrenabaque
# Processing Record 64 for horqueta , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=horqueta
# Processing Record 65 for teno , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=teno
# Processing Record 66 for sao geraldo do araguaia , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao geraldo do araguaia
# Processing Record 67 for matara , lk
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=matara
# Processing Record 68 for areia branca , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=areia branca
# Processing Record 69 for palmeirais , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=palmeirais
# Processing Record 70 for doctor pedro p. pena , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=doctor pedro p. pena
# Processing Record 71 for katobu , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=katobu
# Processing Record 72 for perth , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=perth
# Processing Record 73 for biak , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=biak
# Processing Record 74 for puerto pinasco , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=puerto pinasco
# Processing Record 75 for ngorongoro , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ngorongoro
# Processing Record 76 for llaillay , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=llaillay
# Processing Record 77 for wolmaranstad , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=wolmaranstad
# Processing Record 78 for baiao , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=baiao
# Processing Record 79 for rio cuarto , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rio cuarto
# Processing Record 80 for sombrio , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sombrio
# Processing Record 81 for hennenman , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=hennenman
# Processing Record 82 for arraial do cabo , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=arraial do cabo
# Processing Record 83 for natalio , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=natalio
# Processing Record 84 for florida , uy
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=florida
# Processing Record 85 for chama , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chama
# Processing Record 86 for aracaju , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=aracaju
# Processing Record 87 for port macquarie , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=port macquarie
# Processing Record 88 for ilo , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ilo
# Processing Record 89 for barra do bugres , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=barra do bugres
# Processing Record 90 for dunda , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=dunda
# Processing Record 91 for andevoranto , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=andevoranto
# Processing Record 92 for coracora , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=coracora
# Processing Record 93 for porto de moz , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=porto de moz
# Processing Record 94 for sumbawa , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sumbawa
# Processing Record 95 for deniliquin , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=deniliquin
# Processing Record 96 for sao marcos , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao marcos
# Processing Record 97 for cangucu , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cangucu
# Processing Record 98 for teresina , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=teresina
# Processing Record 99 for kerikeri , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kerikeri
# Processing Record 100 for santa lucia , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santa lucia
# Processing Record 101 for sao francisco , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao francisco
# Processing Record 102 for bondowoso , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bondowoso
# Processing Record 103 for san pedro de ycuamandiyu , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=san pedro de ycuamandiyu
# Processing Record 104 for caconda , ao
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=caconda
# Processing Record 105 for guanhaes , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=guanhaes
# Processing Record 106 for tsabong , bw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tsabong
# Processing Record 107 for djambala , cg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=djambala
# Processing Record 108 for laguna , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=laguna
# Processing Record 109 for laje , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=laje
# Processing Record 110 for gambiran , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gambiran
# Processing Record 111 for canavieiras , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=canavieiras
# Processing Record 112 for kindu , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kindu
# Processing Record 113 for chiredzi , zw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chiredzi
# Processing Record 114 for bambanglipuro , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bambanglipuro
# Processing Record 115 for monteagudo , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=monteagudo
# Processing Record 116 for voh , nc
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=voh
# Processing Record 117 for masvingo , zw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=masvingo
# Processing Record 118 for sesheke , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sesheke
# Processing Record 119 for lithgow , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lithgow
# Processing Record 120 for zarate , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=zarate
# Processing Record 121 for ayaviri , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ayaviri
# Processing Record 122 for alenquer , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=alenquer
# Processing Record 123 for ambunti , pg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ambunti
# Processing Record 124 for morondava , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=morondava
# Processing Record 125 for mahenge , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mahenge
# Processing Record 126 for ladario , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ladario
# Processing Record 127 for westport , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=westport
# Processing Record 128 for whyalla , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=whyalla
# Processing Record 129 for pilao arcado , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pilao arcado
# Processing Record 130 for cairns , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cairns
# Processing Record 131 for axim , gh
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=axim
# Processing Record 132 for upington , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=upington
# Processing Record 133 for lagunas , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lagunas
# Processing Record 134 for morro da fumaca , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=morro da fumaca
# Processing Record 135 for juquitiba , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=juquitiba
# Processing Record 136 for diamantina , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=diamantina
# Processing Record 137 for oxapampa , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=oxapampa
# Processing Record 138 for mahalapye , bw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mahalapye
# Processing Record 139 for antsohihy , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=antsohihy
# Processing Record 140 for capao bonito , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=capao bonito
# Processing Record 141 for thyolo , mw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=thyolo
# Processing Record 142 for armidale , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=armidale
# Processing Record 143 for francistown , bw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=francistown
# Processing Record 144 for mala , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mala
# Processing Record 145 for mariental , na
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mariental
# Processing Record 146 for utinga , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=utinga
# Processing Record 147 for marcona , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=marcona
# Processing Record 148 for mulchen , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mulchen
# Processing Record 149 for mahajanga , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mahajanga
# Processing Record 150 for ortigueira , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ortigueira
# Processing Record 151 for san lazaro , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=san lazaro
# Processing Record 152 for guanambi , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=guanambi
# Processing Record 153 for cobija , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cobija
# Processing Record 154 for santiago de cao , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santiago de cao
# Processing Record 155 for mafinga , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mafinga
# Processing Record 156 for oeiras do para , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=oeiras do para
# Processing Record 157 for neuquen , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=neuquen
# Processing Record 158 for chitipa , mw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chitipa
# Processing Record 159 for oruro , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=oruro
# Processing Record 160 for uba , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=uba
# Processing Record 161 for opuwo , na
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=opuwo
# Processing Record 162 for urucui , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=urucui
# Processing Record 163 for tobias barreto , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tobias barreto
# Processing Record 164 for padre bernardo , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=padre bernardo
# Processing Record 165 for yauya , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=yauya
# Processing Record 166 for graneros , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=graneros
# Processing Record 167 for sao raimundo nonato , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao raimundo nonato
# Processing Record 168 for pitimbu , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pitimbu
# Processing Record 169 for richards bay , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=richards bay
# Processing Record 170 for sola , vu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sola
# Processing Record 171 for machali , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=machali
# Processing Record 172 for formoso do araguaia , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=formoso do araguaia
# Processing Record 173 for bahia blanca , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bahia blanca
# Processing Record 174 for catamarca , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=catamarca
# Processing Record 175 for santa helena de goias , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santa helena de goias
# Processing Record 176 for ananas , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ananas
# Processing Record 177 for loubomo , cg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=loubomo
# Processing Record 178 for pontal do parana , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pontal do parana
# Processing Record 179 for mugumu , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mugumu
# Processing Record 180 for butia , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=butia
# Processing Record 181 for beloha , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=beloha
# Processing Record 182 for trairi , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=trairi
# Processing Record 183 for jatai , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jatai
# Processing Record 184 for saint-philippe , re
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=saint-philippe
# Processing Record 185 for talcahuano , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=talcahuano
# Processing Record 186 for sinazongwe , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sinazongwe
# Processing Record 187 for cerro largo , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cerro largo
# Processing Record 188 for springbok , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=springbok
# Processing Record 189 for rio gallegos , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rio gallegos
# Processing Record 190 for nhamunda , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nhamunda
# Processing Record 191 for buritis , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=buritis
# Processing Record 192 for loandjili , cg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=loandjili
# Processing Record 193 for nelson bay , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nelson bay
# Processing Record 194 for sao paulo de olivenca , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sao paulo de olivenca
# Processing Record 195 for manokwari , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=manokwari
# Processing Record 196 for muncar , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=muncar
# Processing Record 197 for launceston , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=launceston
# Processing Record 198 for picota , pe
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=picota
# Processing Record 199 for monze , zm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=monze
# Processing Record 200 for kasongo-lunda , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kasongo-lunda
# Processing Record 201 for moba , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=moba
# Processing Record 202 for monte alegre , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=monte alegre
# Processing Record 203 for kununurra , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kununurra
# Processing Record 204 for san alberto , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=san alberto
# Processing Record 205 for eucaliptus , bo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=eucaliptus
# Processing Record 206 for tolaga bay , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tolaga bay
# Processing Record 207 for mangochi , mw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mangochi
# Processing Record 208 for boca do acre , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=boca do acre
# Processing Record 209 for rio tercero , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rio tercero
# Processing Record 210 for port lincoln , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=port lincoln
# Processing Record 211 for buseresere , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=buseresere
# Processing Record 212 for narrabri , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=narrabri
# Processing Record 213 for aurora , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=aurora
# Processing Record 214 for coremas , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=coremas
# Processing Record 215 for bocaiuva , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bocaiuva
# Processing Record 216 for vitoria da conquista , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vitoria da conquista
# Processing Record 217 for irece , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=irece
# Processing Record 218 for lumajang , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lumajang
# Processing Record 219 for nkayi , cg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nkayi
# Processing Record 220 for arraias , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=arraias
# Processing Record 221 for posse , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=posse
# Processing Record 222 for buala , sb
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=buala
# Processing Record 223 for kilosa , tz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kilosa
# Processing Record 224 for grand gaube , mu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=grand gaube
# Processing Record 225 for grand baie , mu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=grand baie
# Processing Record 226 for vera cruz , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vera cruz
# Processing Record 227 for punta alta , ar
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=punta alta
# Processing Record 228 for trenggalek , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=trenggalek
# Processing Record 229 for alvinopolis , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=alvinopolis
# Processing Record 230 for waitati , nz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=waitati
# Processing Record 231 for barreirinha , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=barreirinha
# Processing Record 232 for gamboma , cg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gamboma
# Processing Record 233 for tamandare , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tamandare
# Processing Record 234 for manacapuru , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=manacapuru
# Processing Record 235 for jacareacanga , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jacareacanga
# Processing Record 236 for salamanca , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=salamanca
# Processing Record 237 for bukama , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bukama
# Processing Record 238 for gandajika , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gandajika
# Processing Record 239 for devonport , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=devonport
# Processing Record 240 for antsirabe , mg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=antsirabe
# Processing Record 241 for newcastle , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=newcastle
# Processing Record 242 for mozarlandia , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mozarlandia
# Processing Record 243 for vryburg , za
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vryburg
# Processing Record 244 for gwanda , zw
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gwanda
# Processing Record 245 for gunnedah , au
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gunnedah
# Processing Record 246 for salgueiro , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=salgueiro
# Processing Record 247 for ayolas , py
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ayolas
# Processing Record 248 for antofagasta , cl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=antofagasta
# Processing Record 249 for tacuarembo , uy
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tacuarembo
# Processing Record 250 for bella union , uy
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bella union
# Processing Record 251 for kimparana , ml
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kimparana
# Processing Record 252 for vesele , ua
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vesele
# Processing Record 253 for tahta , eg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tahta
# Processing Record 254 for temascalcingo , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=temascalcingo
# Processing Record 255 for randazzo , it
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=randazzo
# Processing Record 256 for pitiquito , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pitiquito
# Processing Record 257 for port hawkesbury , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=port hawkesbury
# Processing Record 258 for cienaga , co
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cienaga
# Processing Record 259 for krasnozerskoye , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=krasnozerskoye
# Processing Record 260 for macrohon , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=macrohon
# Processing Record 261 for valdez , ec
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=valdez
# Processing Record 262 for nador , ma
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nador
# Processing Record 263 for kavos , gr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kavos
# Processing Record 264 for geresk , af
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=geresk
# Processing Record 265 for sentyabrskiy , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sentyabrskiy
# Processing Record 266 for ayorou , ne
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ayorou
# Processing Record 267 for jawa , jo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jawa
# Processing Record 268 for asfi , ma
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=asfi
# Processing Record 269 for nadadores , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nadadores
# Processing Record 270 for locri , it
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=locri
# Processing Record 271 for bozhou , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bozhou
# Processing Record 272 for zhengjiatun , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=zhengjiatun
# Processing Record 273 for west odessa , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=west odessa
# Processing Record 274 for bandarbeyla , so
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bandarbeyla
# Processing Record 275 for chor , pk
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chor
# Processing Record 276 for fort smith , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=fort smith
# Processing Record 277 for san onofre , co
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=san onofre
# Processing Record 278 for russkiy , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=russkiy
# Processing Record 279 for camalu , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=camalu
# Processing Record 280 for mountain home , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mountain home
# Processing Record 281 for jaruco , cu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jaruco
# Processing Record 282 for liuhe , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=liuhe
# Processing Record 283 for yook , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=yook
# Processing Record 284 for przasnysz , pl
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=przasnysz
# Processing Record 285 for ndele , cf
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ndele
# Processing Record 286 for nueva italia de ruiz , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nueva italia de ruiz
# Processing Record 287 for mahasamund , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mahasamund
# Processing Record 288 for tabulbah , tn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tabulbah
# Processing Record 289 for coulihaut , dm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=coulihaut
# Processing Record 290 for barentsburg , sj
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=barentsburg
# Processing Record 291 for tra vinh , vn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tra vinh
# Processing Record 292 for harer , et
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=harer
# Processing Record 293 for bowmore , gb
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bowmore
# Processing Record 294 for redwater , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=redwater
# Processing Record 295 for franklin , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=franklin
# Processing Record 296 for portlethen , gb
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=portlethen
# Processing Record 297 for salinopolis , br
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=salinopolis
# Processing Record 298 for tamiahua , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tamiahua
# Processing Record 299 for eregli , tr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=eregli
# Processing Record 300 for kita , ml
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kita
# Processing Record 301 for zavodouspenskoye , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=zavodouspenskoye
# Processing Record 302 for devils lake , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=devils lake
# Processing Record 303 for sinkat , sd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sinkat
# Processing Record 304 for pyay , mm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pyay
# Processing Record 305 for gallipoli , it
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gallipoli
# Processing Record 306 for gibara , cu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gibara
# Processing Record 307 for pyinmana , mm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=pyinmana
# Processing Record 308 for mae hong son , th
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mae hong son
# Processing Record 309 for porto-vecchio , fr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=porto-vecchio
# Processing Record 310 for ejura , gh
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ejura
# Processing Record 311 for cedar city , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=cedar city
# Processing Record 312 for bargal , so
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bargal
# Processing Record 313 for fairhope , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=fairhope
# Processing Record 314 for tostamaa , ee
# ...
# Processing Record 397 for sikandarpur , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sikandarpur
# Processing Record 398 for jiaozuo , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jiaozuo
# Processing Record 399 for jabinyanah , tn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jabinyanah
# Processing Record 400 for saint-malo , fr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=saint-malo
# Processing Record 401 for roslavl , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=roslavl
# Processing Record 402 for two hills , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=two hills
# Processing Record 403 for rudbar , af
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rudbar
# Processing Record 404 for gigmoto , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=gigmoto
# Processing Record 405 for kuantan , my
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kuantan
# Processing Record 406 for bagotville , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bagotville
# Processing Record 407 for kodar , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kodar
# Processing Record 408 for paveh , ir
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=paveh
# Processing Record 409 for olutanga , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=olutanga
# Processing Record 410 for ponte de sor , pt
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ponte de sor
# Processing Record 411 for dingli , mt
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=dingli
# Processing Record 412 for bezhanitsy , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bezhanitsy
# Processing Record 413 for lawrenceburg , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lawrenceburg
# Processing Record 414 for sulurpeta , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sulurpeta
# Processing Record 415 for lamidan , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lamidan
# Processing Record 416 for tchollire , cm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tchollire
# Processing Record 417 for chisinau , md
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chisinau
# Processing Record 418 for lenine , ua
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lenine
# Processing Record 419 for stepnyak , kz
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=stepnyak
# Processing Record 420 for wadena , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=wadena
# Processing Record 421 for manama , bh
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=manama
# Processing Record 422 for nam tha , la
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=nam tha
# Processing Record 423 for faridan , ir
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=faridan
# Processing Record 424 for barillas , gt
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=barillas
# Processing Record 425 for meiktila , mm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=meiktila
# Processing Record 426 for bakchar , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bakchar
# Processing Record 427 for verkhnya syrovatka , ua
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=verkhnya syrovatka
# Processing Record 428 for maturin , ve
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=maturin
# Processing Record 429 for tizimin , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tizimin
# Processing Record 430 for jacqueville , ci
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=jacqueville
# Processing Record 431 for larap , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=larap
# Processing Record 432 for hengyang , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=hengyang
# Processing Record 433 for autun , fr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=autun
# Processing Record 434 for rosetown , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rosetown
# Processing Record 435 for kadyy , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kadyy
# Processing Record 436 for khandagayty , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=khandagayty
# Processing Record 437 for vengerovo , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vengerovo
# Processing Record 438 for ashtabula , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ashtabula
# Processing Record 439 for navahrudak , by
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=navahrudak
# Processing Record 440 for teseney , er
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=teseney
# Processing Record 441 for dapdap , ph
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=dapdap
# Processing Record 442 for madinat sittah uktubar , eg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=madinat sittah uktubar
# Processing Record 443 for lao cai , vn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=lao cai
# Processing Record 444 for hoa binh , vn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=hoa binh
# Processing Record 445 for kerouane , gn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kerouane
# Processing Record 446 for binga , cd
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=binga
# Processing Record 447 for krabi , th
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=krabi
# Processing Record 448 for terrak , no
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=terrak
# Processing Record 449 for podor , sn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=podor
# Processing Record 450 for ellensburg , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ellensburg
# Processing Record 451 for chirkey , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=chirkey
# Processing Record 452 for rognan , no
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rognan
# Processing Record 453 for uyemskiy , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=uyemskiy
# Processing Record 454 for real , pt
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=real
# Processing Record 455 for luoyang , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=luoyang
# Processing Record 456 for korcula , hr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=korcula
# Processing Record 457 for rangoon , mm
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=rangoon
# Processing Record 458 for glasgow , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=glasgow
# Processing Record 459 for saravan , la
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=saravan
# Processing Record 460 for elat , il
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=elat
# Processing Record 461 for asyut , eg
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=asyut
# Processing Record 462 for truth or consequences , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=truth or consequences
# Processing Record 463 for sibolga , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sibolga
# Processing Record 464 for santa cruz del sur , cu
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santa cruz del sur
# Processing Record 465 for mehran , ir
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mehran
# Processing Record 466 for bloomfield , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bloomfield
# Processing Record 467 for vagur , fo
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=vagur
# Processing Record 468 for hesla , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=hesla
# Processing Record 469 for puerto del rosario , es
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=puerto del rosario
# Processing Record 470 for el seibo , do
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=el seibo
# Processing Record 471 for linares , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=linares
# Processing Record 472 for one hundred mile house , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=one hundred mile house
# Processing Record 473 for prachuap khiri khan , th
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=prachuap khiri khan
# Processing Record 474 for bodden town , ky
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bodden town
# Processing Record 475 for sigli , id
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sigli
# Processing Record 476 for tayshet , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=tayshet
# Processing Record 477 for bechem , gh
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bechem
# Processing Record 478 for southampton , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=southampton
# Processing Record 479 for warrington , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=warrington
# Processing Record 480 for svolvaer , no
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=svolvaer
# Processing Record 481 for zanesville , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=zanesville
# Processing Record 482 for santa isabel , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=santa isabel
# Processing Record 483 for smiths falls , ca
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=smiths falls
# Processing Record 484 for roswell , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=roswell
# Processing Record 485 for verkhoturye , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=verkhoturye
# Processing Record 486 for uruzgan , af
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=uruzgan
# Processing Record 487 for ratnagiri , in
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ratnagiri
# Processing Record 488 for yusva , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=yusva
# Processing Record 489 for constitucion , mx
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=constitucion
# Processing Record 490 for ajaccio , fr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ajaccio
# Processing Record 491 for kirchzarten , de
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=kirchzarten
# Processing Record 492 for voyvozh , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=voyvozh
# Processing Record 493 for alamogordo , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=alamogordo
# Processing Record 494 for sukhothai , th
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sukhothai
# Processing Record 495 for segezha , ru
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=segezha
# Processing Record 496 for odemis , tr
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=odemis
# Processing Record 497 for ziyang , cn
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=ziyang
# Processing Record 498 for mbini , gq
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=mbini
# Processing Record 499 for sungai siput utara , my
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=sungai siput utara
# Processing Record 500 for bastrop , us
# http://api.openweathermap.org/data/2.5/weather?appid=f5b7d2d713e23759aa5edd5604694c1e&units=imperial&q=bastrop
#                 Data Retrieval Complete

# %%
latitude  = []
longtitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
city = []
country = []
max_temp = []


for data in weather_json:
    try:

        lat1 = data.get("coord").get("lat")
        latitude.append(lat1)
        temp1 = data.get("main").get("temp")
        temperature.append(temp1)
        city1 = data.get("name")
        city.append(city1)
        country1 = data.get("sys").get("country")
        country.append(country1)
        humi1 = data.get("main").get("humidity")
        humidity.append(humi1)
        cld1 = data.get("clouds").get("all")
        cloudiness.append(cld1)
        wind1 = data.get("wind").get("speed")
        wind_speed.append(wind1)
        long1 = data.get("coord").get("lon")
        longtitude.append(long1)
        temp1 = data.get("main").get("temp_max")
        max_temp.append(temp1)
        
    except:
        pass

    continue

weather_dict = {"city":city, "Temperature (F)": temperature, "Latitude": latitude, "Longitude":longtitude, "Country":country,
                "Humidity": humidity, "Cloudiness":cloudiness,"Wind_Speed":wind_speed, "Max_Temp":max_temp}
weather_df = pd.DataFrame(weather_dict)
weather_df.to_csv(data_file+'_'+str(now)+'.csv', sep='\t')


weather_df.head()
# Out:
#          city  Temperature (F)  Latitude  Longitude Country  Humidity  \
# 0      Liwale            68.90     -9.80      37.92      TZ        73
# 1   Warkworth            50.00    -36.40     174.66      NZ        93
# 2  Ngerengere            74.75     -6.76      38.13      TZ        84
# 3   Kadungora            65.30     -7.09     107.89      ID        98
# 4     Conchas            60.62    -23.02     -48.01      BR        60
#
#    Cloudiness  Wind_Speed  Max_Temp
# 0           0        4.61     68.90
# 1           0        3.36     50.00
# 2          68        3.60     74.75
# 3          80        1.25     65.30
# 4           8        5.39     60.62

# %%
#check for sample totals
len(weather_df)
# Out:
# 450

# %%
plt.title("Sample Distribution for \n"+str(now))
plt.scatter(weather_df.Longitude,weather_df.Latitude,facecolors="red",s=5, edgecolors="black",alpha=0.75)

# %%
sns.kdeplot(weather_df.Max_Temp,weather_df.Latitude,{'axes.grid': True},cmap="icefire",alpha=0.45)
plt.scatter(weather_df.Max_Temp,weather_df.Latitude,facecolors="red",s=50, edgecolors="black",alpha=0.65)

plt.title("Max Temp vs Max Temp for \n"+str(now))
plt.xlabel("Max Temp")
plt.ylabel("Latitude \n South Hemisphere         North Hemisphere", multialignment='center')
plt.ylim((-90,90))
plt.xlim((min(weather_df.Max_Temp)-5,max(weather_df.Max_Temp)+5))


plt.savefig("Latitude V Max Temp"+'_'+str(now)+'.png')

# %% [markdown]
# __ Temperature V Latitude__<br>
# Density and scatter plot combined in the above plot shows a clear relationship.<br>
# Temperatures nearer the equator are warmer.<br>
# This relationship will be expected to fluctuate.<br>

# %%
sns.kdeplot(weather_df.Wind_Speed,weather_df.Latitude,{'axes.grid': True},cmap="icefire",alpha=0.35)
plt.scatter(weather_df.Wind_Speed,weather_df.Latitude,facecolors="black", edgecolors="white",s=50,alpha=0.55)

plt.title("Wind Speed V Latitude \n"+str(now))
plt.xlabel("Wind Speed")
plt.ylabel("Latitude \n South Hemisphere         North Hemisphere", multialignment='center')

plt.ylim((-90,90))
plt.xlim((-5,max(weather_df.Wind_Speed)+5))


plt.savefig("Wind Speed V Latitude"+'_'+str(now)+'.png')

# %% [markdown]
# __Wind Speed V Latitude__<br>
# In the above chart you can notice that the higher windspeeds are more common farther<br>
# from the equator.

# %%
sns.kdeplot(weather_df.Humidity,weather_df.Latitude,{'axes.grid': True},cmap="cubehelix_r",alpha=0.45)
plt.scatter(weather_df.Humidity,weather_df.Latitude, facecolors="blue",s=45, edgecolors="black",alpha=0.65)

plt.title("Humidity vs Latitude\n"+str(now))
plt.xlabel("Humidity")
plt.ylabel("Latitude \n South Hemisphere         North Hemisphere", multialignment='center')

plt.ylim((-90,90))
plt.xlim((-20,max(weather_df.Humidity)+10))



plt.savefig("Humidity V Latitude"+'_'+str(now)+'.png')

# %% [markdown]
# __Humidity V Latitude__<br>
# In the above chart you can notice that the higher humidities are more common closer<br>
# to the equator.

# %%
plt.title("Cloudiness vs Latitude \n"+str(now))
sns.kdeplot(weather_df.Cloudiness,weather_df.Latitude,{'axes.grid': True},cmap="bone")
plt.scatter(weather_df.Cloudiness,weather_df.Latitude, facecolors="White",s=45, edgecolors="black",alpha=0.45)

plt.ylabel("Latitude \n South Hemisphere         North Hemisphere", multialignment='center')

plt.ylim((-90,90))
plt.xlim((-20,max(weather_df.Cloudiness)+10))

plt.savefig("Cloudiness vs Latitude"+'_'+str(now)+'.png')

# %% [markdown]
# __Clouds V Latitude__<br>
# In the above chart you can see that cloudy conditions are most prevalent closer<br>
# to the equator.
